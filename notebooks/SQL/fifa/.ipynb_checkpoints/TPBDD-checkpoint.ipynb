# %%
import sqlite3
import pandas as pd
con=sqlite3.connect("worldcup.db")
sql=lambda requete:pd.read_sql_query(requete,con)

# %%
sql("""
select * from goals
where team_id=45
""")
# Out:
# Empty DataFrame
# Columns: [goal_id, tournament_id, match_id, team_id, home_team, away_team, player_id, shirt_number, player_team_id, minute_label, minute_regulation, minute_stoppage, match_period, own_goal, penalty]
# Index: []

# %%
sql("""
select family_name

""")
# Out:
#      player_id   family_name given_name  birth_date  goal_keeper  defender  \
# 0      P-08891       A'Court       Alan  1934-09-30            0         0
# 1      P-08589      Aaronson    Brenden  2000-10-22            0         0
# 2      P-04897     Abadzhiev     Stefan  1934-07-03            0         0
# 3      P-05556         Abalo  Jean-Paul  1975-06-26            0         1
# 4      P-08163        Abanda    Patrice  1978-08-03            0         1
# ...        ...           ...        ...         ...          ...       ...
# 8480   P-06718      Żurawski     Maciej  1976-09-12            0         0
# 8481   P-03465     Żurkowski     Szymon  1997-09-25            0         0
# 8482   P-08318          Zusi     Graham  1986-08-18            0         0
# 8483   P-05921  Zygmantovich     Andrei  1962-12-02            0         0
# 8484   P-03072         Zykov     Valery  1944-02-24            0         0
#
#       midfielder  forward  count_tournaments list_tournaments  \
# ...
